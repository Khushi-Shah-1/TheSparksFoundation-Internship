# %% [markdown]
# # Author : Khushi Shah
#
# ## The Sparks Foundation- Data Science & Business Analytics Intern
#
# ## Task 3
#
# ### Problem Statement:- As a business Manager, try to find out the weak areas where you can work to make more profit. What all business problems you can derive by exploring the data?

# %%
# Importing libraries PANDAS,NUMPY for data manuplation, Matplotlib,seaborn module for Data Visualisation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read the csv file
data = pd.read_csv('SampleSuperstore.csv')

# %% [markdown]
# ### Basic Data Insights

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
# Ship Mode       9994 non-null object
# Segment         9994 non-null object
# Country         9994 non-null object
# City            9994 non-null object
# State           9994 non-null object
# Postal Code     9994 non-null int64
# Region          9994 non-null object
# Category        9994 non-null object
# Sub-Category    9994 non-null object
# Sales           9994 non-null float64
# Quantity        9994 non-null int64
# Discount        9994 non-null float64
# Profit          9994 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.shape
# Out:
# (9994, 13)

# %% [markdown]
# ### Number of unique values in each column

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ### We can see there are no null values

# %%
data.drop('Postal Code', axis = 1, inplace = True)

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Univariate Analysis

# %%
data['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
# looking at it percentage wise
(data['Ship Mode'].value_counts()/len(data['Ship Mode']))*100
# Out:
# Standard Class    59.715829
# Second Class      19.461677
# First Class       15.389234
# Same Day           5.433260
# Name: Ship Mode, dtype: float64

# %%
((data['Ship Mode'].value_counts()/len(data['Ship Mode']))*100).plot(kind="bar", color="green")

# %% [markdown]
# ### Conclusions that can be made from the above graph:
# #### 1) More than 50% of deliveries belong to standard class
# #### 2) Very less deliveries were done on the same day

# %%
data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
(data['Segment'].value_counts()/len(data['Ship Mode']))*100
# Out:
# Consumer       51.941165
# Corporate      30.218131
# Home Office    17.840704
# Name: Segment, dtype: float64

# %%
((data['Segment'].value_counts()/len(data['Ship Mode']))*100).plot(kind="bar", color="green")

# %% [markdown]
# ### Conclusions that can be made from the above graph:
# #### 1)  More than 50% of people belong to consumer class
# #### 2)  Almost 30% of people belong to corporate class
# #### 3)  Almost 18% of people belong to Home office class

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
(data['Category'].value_counts()/len(data['Ship Mode']))*100
# Out:
# Office Supplies    60.296178
# Furniture          21.222734
# Technology         18.481089
# Name: Category, dtype: float64

# %%
((data['Category'].value_counts()/len(data['Ship Mode']))*100).plot(kind="bar", color="green")

# %% [markdown]
# ### Conclusions that can be made from the above graph:
# #### 1)  Almost 60% of products belong to Office supplies
# #### 2)  More than 21% of product belong to Furniture
# #### 3)  Almost 18% of product belong to Technology

# %%
data['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
(data['Sub-Category'].value_counts()/len(data['Ship Mode']))*100
# Out:
# Binders        15.239143
# Paper          13.708225
# Furnishings     9.575745
# Phones          8.895337
# Storage         8.465079
# Art             7.964779
# Accessories     7.754653
# Chairs          6.173704
# Appliances      4.662798
# Labels          3.642185
# Tables          3.191915
# Envelopes       2.541525
# Bookcases       2.281369
# Fasteners       2.171303
# Supplies        1.901141
# Machines        1.150690
# Copiers         0.680408
# Name: Sub-Category, dtype: float64

# %%
((data['Sub-Category'].value_counts()/len(data['Ship Mode']))*100).plot(kind="bar", color="green")

# %% [markdown]
# ### Conclusions that can be made from the above graph:
# #### 1) Binders and Papers which fall into office supplies category have the highest quantity

# %% [markdown]
# ## Bivariate Analysis

# %%
#correlation matrix
data.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
fig, axes = plt.subplots(1,1, figsize = (8,5))
sns.heatmap(data.corr())
plt.show()

# %% [markdown]
# ### Here we can see discount and profit are highly negatively corelated

# %% [markdown]
# #### Values closer to zero means there is no linear trend between the two variables.
# #### The close to 1 the correlation is the more positively correlated they are; that is as one increases so does the other and
# #### the closer to 1 the stronger this relationship is. A correlation closer to -1 is similar,
# #### but instead of both increasing one variable will decrease as the other increases

# %%
sns.catplot(x='Category',y='Profit',data=data,col="Region")

# %%
plt.figure(figsize=(10,10))
data.groupby('Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.show()

# %% [markdown]
# ### From the above graph we can see that the sales of furniture is good still profit is lowest

# %%
plt.figure(figsize=(24,10))
data.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.show()

# %%
plt.figure(figsize=(24,10))
data.groupby('Sub-Category')['Profit'].agg(['sum']).plot.bar()
plt.show()

# %% [markdown]
# ### From the above figure we can see that the
# ### 1) Sale of tables is high but it is producing loss
# ### 2) There is a negligible loss from Bookcases and suppliers
# ### 3) There is almost negligible sale and profit from fasteners
# ### 4) Copiers are giving the highest profit

# %%
sns.barplot(x=data.Discount,y=data.Profit)

# %% [markdown]
# ### From the above graph we can see that from more than 20% discount loss is happening

# %%
sns.barplot(x=data.Region, y=data.Sales)

# %%
sns.barplot(x=data.Region, y=data.Profit)

# %%
sns.barplot(x=data.Region, y=data.Profit,hue=data.Category)

# %% [markdown]
# ### 1) For the central region the Furniture category is making most loss.
# ### 2) Technology is giving the highest profit in every region

# %%
sns.barplot(x=data.Region, y=data.Profit,hue=data.Segment)

# %% [markdown]
# ### From the above figure we can see that the West region produces highest net profit and East region is producing very high profit in Home office segment while the lowest profit was in Central region in consumer segment.

# %%
dataplot = data.groupby(['State'])['Sales', 'Profit'].sum()
dataplot.plot.bar(figsize = (20,10))

# %% [markdown]
# ### we can see that there are some states with loss

# %%
dataplot = data.groupby(['State'])['Profit'].sum()
dataplot.plot.bar(figsize = (20,10))

# %% [markdown]
# ### The states producing loss are Arizona, Colarado, Florida, illinois, North Carolina, Ohio, Pennsylvania, Tennesee, Texas
# ### Texas, Ohio, Illinois and Pennsylvania are incurring huge loss even when the sale is good
# ### New York and California are making the highest profit

# %%
dataplot = data.groupby(['State']).Discount.sum()
plt.xlabel('States')
plt.ylabel('Discount')
dataplot.plot.bar(figsize = (20,10))

# %% [markdown]
# ### Texas is giving very high discounts and thus incurring huge loss. The same is the case with Illinois, Ohio and Pennsylvania.

# %% [markdown]
# # FINAL CONCLUSION
# ### 1) The sale of tables should be stopped as it is producing high loss
# ### 2) Bookcases and suppliers are producing negligible loss so their price should be increased or sale should be stopped
# ### 3) For the central region we should definitely look into the Furniture category as we are suffering most losses there.
# ### 4) The supply of Technology should be increased as it appears to be a promising way to increase profits exponentially as all the regions are gaining high profit from it.
# ### 5) Texas, Ohio, illinois and Pennsylvania are incurring huge loss even when the sale is good and the main reason is huge discounts. So, we should consider reducing these discounts if we want a profit.
# ### 6)  From the bar graph we could see that from more than 20% discount, loss is happening so we should not give anymore than 20% discount in all the states especially the states incurring loss at the moment
#
#
# # This concludes our analysis for this task.
